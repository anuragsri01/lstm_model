# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragsri01/lstm_model/blob/master/car_fuel_meter_reading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-904921f1-0c41-4745-9abe-92e4944767c0" name="files[]" multiple disabled />
#      <output id="result-904921f1-0c41-4745-9abe-92e4944767c0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
image = cv2.imread('txt_nikate_b10_1_93.jpg')

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7FF9C8B0F358>
